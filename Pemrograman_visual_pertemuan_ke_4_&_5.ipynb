# %% [markdown]
# <a href="https://colab.research.google.com/github/Sihjp/Pemrograman-Visual_S4/blob/main/Pemrograman_visual_pertemuan_ke_4_%26_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Lima Lingkaran

print ("\033c")

import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(-8,8,10000)
plt.figure(figsize=(8,6.5))

y = x -x -0
y1 = (4 -x**2)**0.5
y2 = -(4 -x**2)**0.5

y3 = 5 + (4-(x-5)**2)**0.5
y4 = 5 - (4-(x-5)**2)**0.5

y5 = -5 + (4-(x-5)**2)**0.5
y6 = -5 - (4-(x-5)**2)**0.5

y7 = 5 + (4-(x+5)**2)**0.5
y8 = 5 - (4-(x+5)**2)**0.5

y9 = -5 + (4-(x+5)**2)**0.5
y10 = -5 - (4-(x+5)**2)**0.5

plt.plot(x, y, '-k')
plt.plot(x, y1, '-r', label='y1, y2')
plt.plot(x, y2, '-r')
plt.plot(x, y3, '-g', label='y3, y4')
plt.plot(x, y4, '-g')
plt.plot(x, y5, '-b', label='y5, y6')
plt.plot(x, y6, '-b')
plt.plot(x, y7, '-y', label='y7, y8')
plt.plot(x, y8, '-y')
plt.plot(x, y9, '-m', label='y9, y10')
plt.plot(x, y10, '-m')

plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-11-dd807d99f986>:13: RuntimeWarning: invalid value encountered in sqrt
#   y1 = (4 -x**2)**0.5
# <ipython-input-11-dd807d99f986>:14: RuntimeWarning: invalid value encountered in sqrt
#   y2 = -(4 -x**2)**0.5
# <ipython-input-11-dd807d99f986>:16: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 5 + (4-(x-5)**2)**0.5
# <ipython-input-11-dd807d99f986>:17: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 5 - (4-(x-5)**2)**0.5
# <ipython-input-11-dd807d99f986>:19: RuntimeWarning: invalid value encountered in sqrt
#   y5 = -5 + (4-(x-5)**2)**0.5
# <ipython-input-11-dd807d99f986>:20: RuntimeWarning: invalid value encountered in sqrt
#   y6 = -5 - (4-(x-5)**2)**0.5
# <ipython-input-11-dd807d99f986>:22: RuntimeWarning: invalid value encountered in sqrt
#   y7 = 5 + (4-(x+5)**2)**0.5
# <ipython-input-11-dd807d99f986>:23: RuntimeWarning: invalid value encountered in sqrt
#   y8 = 5 - (4-(x+5)**2)**0.5
# ...

# %%
# Latihan mickeymouse
print ("\033c")

import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(-10,10,10000)
plt.figure(figsize=(10,6.5))

y = x -x -0
y1 = 5 + (5-(x-5)**2)**0.5
y2 = 5 - (5-(x-5)**2)**0.5

y3 = 7 + (2-(x-3)**2)**0.5
y4 = 7 - (2-(x-3)**2)**0.5

y5 = 7 + (2-(x-7)**2)**0.5

y6 = 7 - (2-(x-7)**2)**0.5

plt.plot(x, y, '-k')
plt.plot(x, y1, '-g', label='y1, y2')
plt.plot(x, y2, '-g')

plt.plot(x, y3, '-r', label='y3, y4')
plt.plot(x, y4, '-r')

plt.plot(x, y5, '-b', label='y5, y6')
plt.plot(x, y6, '-b')

plt.fill_between(x, y1, y2, color='black')
plt.fill_between(x, y3, y4, color='black')
plt.fill_between(x, y5, y6, color='black')


plt.legend(loc='upper center')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-45-11fe045c7ad3>:12: RuntimeWarning: invalid value encountered in sqrt
#   y1 = 5 + (5-(x-5)**2)**0.5
# <ipython-input-45-11fe045c7ad3>:13: RuntimeWarning: invalid value encountered in sqrt
#   y2 = 5 - (5-(x-5)**2)**0.5
# <ipython-input-45-11fe045c7ad3>:15: RuntimeWarning: invalid value encountered in sqrt
#   y3 = 7 + (2-(x-3)**2)**0.5
# <ipython-input-45-11fe045c7ad3>:16: RuntimeWarning: invalid value encountered in sqrt
#   y4 = 7 - (2-(x-3)**2)**0.5
# <ipython-input-45-11fe045c7ad3>:18: RuntimeWarning: invalid value encountered in sqrt
#   y5 = 7 + (2-(x-7)**2)**0.5
# <ipython-input-45-11fe045c7ad3>:20: RuntimeWarning: invalid value encountered in sqrt
#   y6 = 7 - (2-(x-7)**2)**0.5

# %%
# Realisasi kurva parabolic

print ("\033c")

import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 10000)
plt.figure(figsize=(3,30))

plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -(0.01-x**2)**0.5, '-k')

y = x -x -0
y1 = x**3 - 2*x**2 - 5*x + 6

plt.plot(x, y, '-k')

plt.plot(x, y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
# latihan kurwa parabolic
print ("\033c")

import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(-4, 4, 10000)
plt.figure(figsize=(3,30))

plt.plot(x, (0.01-x**2)**0.5, '-k')
plt.plot(x, -(0.01-x**2)**0.5, '-k')

y = x -x -0
y1 = -(x**3 - 2*x**2 - x + 2)

plt.plot(x, y, '-k')

plt.plot(x, y1, '-r', label='y1')

plt.legend(loc='upper left')
plt.grid()
plt.show()
# Out:
# c
# <ipython-input-53-e2751449eace>:11: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, (0.01-x**2)**0.5, '-k')
# <ipython-input-53-e2751449eace>:12: RuntimeWarning: invalid value encountered in sqrt
#   plt.plot(x, -(0.01-x**2)**0.5, '-k')

# %%
# pertemuan 5

# pemrograman melibatkan data berjenis sets(1)
Set_1 = {"Toyota", "Daihatsu", "Honda"}
Set_2 = set(("Toyota", "Daihatsu", "Honda"))

print("Tipe data Set_1 adalah ", type(Set_1))
print("Tipe data Set_2 adalah ", type(Set_2))
print("Data Set_1: ", Set_1)
print("Data Set_2: ", Set_2)
print("------------------------------------")

for x in Set_1:
    print(x)
print("------------------------------------")

print(len(Set_1))

if "Daihatsu" in Set_1:
    print("Yes, 'Daihatsu is an item in Set_1.")

Set_1.add("Mitsubishi")
print(Set_1)

Set_1.update(["Suzuki", "Mazda", "Nissan"])
print(Set_1)

# Part 2

Set_1.remove("Honda")
print(Set_1)

Set_1.discard("Mazda")
print(Set_1)

Set_1.pop()
print(Set_1)

Set_1.clear()
print(Set_1)

del Set_1
print("------------------------------------")

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = set1.union(set2)
print(set3)
print("------------------------------------")

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set1.update(set2)
print(set1)
print(set2)
# Out:
# Tipe data Set_1 adalah  <class 'set'>
# Tipe data Set_2 adalah  <class 'set'>
# Data Set_1:  {'Toyota', 'Daihatsu', 'Honda'}
# Data Set_2:  {'Toyota', 'Daihatsu', 'Honda'}
# ------------------------------------
# Toyota
# Daihatsu
# Honda
# ------------------------------------
# 3
# Yes, 'Daihatsu is an item in Set_1.
# {'Toyota', 'Daihatsu', 'Honda', 'Mitsubishi'}
# {'Mazda', 'Daihatsu', 'Nissan', 'Suzuki', 'Toyota', 'Honda', 'Mitsubishi'}
# {'Mazda', 'Daihatsu', 'Nissan', 'Suzuki', 'Toyota', 'Mitsubishi'}
# {'Daihatsu', 'Nissan', 'Suzuki', 'Toyota', 'Mitsubishi'}
# {'Nissan', 'Suzuki', 'Toyota', 'Mitsubishi'}
# set()
# ------------------------------------
# {1, 2, 3, 'a', 'c', 'b'}
# ------------------------------------
# {1, 2, 3, 'a', 'c', 'b'}
# {1, 2, 3}

# %%
# Case 1
print("Case 1")

#Data bertipe Boolean yang Kita Deklarasikan (Cara Standar)
f = bool(True)

g = bool(False)

print(f)
print(g)
print("=======================")

#Case 2
print("Case 2")

#Data Bertipe Boolean Dalam Berbagai Konteks
#Tercatat Dengan Sendirinya oleh Komputer tanpa Deklarasi.

print(3>2)
print(3+2==5)
print(3<2)
print("=======================")

#Case 3
print("Case 3")

#Data Bertipe Boolean Dalam Berbagai Konteks
#Tercatat Dengan Sendirinya oleh Komputer tanpa Deklarasi.

Penghasilan = 20000000
PenghasilanTanpaPajak = 4000000

if Penghasilan <= PenghasilanTanpaPajak:
    PajakYangHarusDibayar = 0

if Penghasilan > PenghasilanTanpaPajak:
    PajakYangHarusDibayar = 0.1 * Penghasilan

print("Pajak yang harus Anda bayar: Rp ", PajakYangHarusDibayar)

# PART 2
print("Case 4")

a = 3
b = "Ini data string."
c = ("laptop", "buku", "ballpen")
d = ["laptop", "buku", "ballpen"]
e = {"laptop":"asus", "buku":"buku_teks", "ballpen": "arrow"}
f = {1, 2, 3, 4, 5}

print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
print(bool(f))

print("=======================")

# PART 3

print("Case 5")
a = 0
b = ""
c = ()
d = []
e = {}
print(bool(a))
print(bool(b))
print(bool(c))
print(bool(d))
print(bool(e))
print("=======================")

print("Case 6")

class myclass():
    def __len__(self):
        return 0
print(bool(myclass()))
print("=======================")
# Out:
# Case 1
# True
# False
# ...
# Case 2
# True
# True
# False
# ...
# Case 3
# Pajak yang harus Anda bayar: Rp  2000000.0
# Case 4
# True
# True
# True
# True
# True
# True
# ...
# Case 5
# False
# False
# False
# False
# False
# ...
# Case 6
# False
# ...

# %%
# Latihan set

Set_a = {"Hutao", "Yelan", "Eula", "Shenhe", "Xianyun"}
Set_b = set(("Hutao", "Yelan", "Eula", "Shenhe", "Xianyun"))

print("Tipe data Set_a adalah :", type(Set_a))
print("Tipe data Set_b adalah :", type(Set_b))
print("-------------------------------------")

for x in Set_a:
  print(x)
print("-------------------------------------")

print(len(Set_a))

if "Eula" in Set_a:
  print("Yes, 'Eula is my waifu in Set_a.")

Set_a.add("Yoimiya")
print(Set_a)

Set_a.update(["Hutao", "Yelan", "Eula", "Shenhe", "Xianyun"])
print(Set_a)

Set_a.remove("Hutao")
print(Set_a)

Set_a.discard("Yoimiya")
print(Set_a)

Set_a.pop()
print(Set_a)

Set_a.clear()
print(Set_a)

del Set_a
print("-------------------------------------")

Seta = {"Hutao", "Yelan", "Eula", "Shenhe", "Xianyun"}
Setb = {"Hydro", "Pyro", "Cryo", "Anemo", "Geo"}

Seta.update(Setb)
print(Seta)
# Out:
# Tipe data Set_a adalah : <class 'set'>
# Tipe data Set_b adalah : <class 'set'>
# -------------------------------------
# Shenhe
# Yelan
# Xianyun
# Eula
# Hutao
# -------------------------------------
# 5
# Yes, 'Eula is my waifu in Set_a.
# {'Shenhe', 'Yelan', 'Yoimiya', 'Xianyun', 'Eula', 'Hutao'}
# {'Shenhe', 'Yelan', 'Yoimiya', 'Xianyun', 'Eula', 'Hutao'}
# {'Shenhe', 'Yelan', 'Yoimiya', 'Xianyun', 'Eula'}
# {'Shenhe', 'Yelan', 'Xianyun', 'Eula'}
# {'Yelan', 'Xianyun', 'Eula'}
# set()
# -------------------------------------
# {'Pyro', 'Geo', 'Xianyun', 'Eula', 'Hydro', 'Hutao', 'Anemo', 'Yelan', 'Cryo', 'Shenhe'}

# %%
# Latihan Boolean

print("Case 1")

f = bool(True)
g = bool(False)

print(f)
print(g)

print("=======================================")

print("Case 2")
print(144>150)
print(120+24==144)
print(150<180)

print("=======================================")

print("Case 3")
Pembelian = 5000000
PembelianTanpaPajak = 2500000

if PembelianTanpaPajak <= Pembelian:
    PajakYangHarusDibayar = 0
if Pembelian > PembelianTanpaPajak:
    PajakYangHarusDibayar = Pembelian - PembelianTanpaPajak
print("Pajak Yang Harus Anda Bayar : Rp. ", PajakYangHarusDibayar)
# Out:
# Case 1
# True
# False
# ...
# Case 2
# False
# True
# True
# ...
# Case 3
# Pajak Yang Harus Anda Bayar : Rp.  2500000
